# %% [markdown]
# Will Albert
# DSSA5102 Gathering & Warehousing
# Mini Project 1 - Analysis with Pandas and Plotly

# %% [markdown]
# ### Import Pandas, Numpy and Plot.ly (offline mode)

# %%
import pandas as pd
import numpy as np

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ### Read data (if file is in same directory as notebook; otherwise, add directory info)
# ### and have a look at the first five rows

# %%
df = pd.read_csv("userssharedsdfschoolimprovement2010grants.csv")
df.head()
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2                     GAMBELL SCHOOL   GAMBELL    AK
# 3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name 2010/11/Award Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT           $471014.00
# 1                     YUPIIT SCHOOL DISTRICT           $520579.00
# 2              BERING STRAIT SCHOOL DISTRICT           $449592.00
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT           $641184.00
# 4                     YUPIIT SCHOOL DISTRICT           $399686.00
#
#    Model Selected                                           Location
# 0  Transformation  200 MAIN ST\nSAVOONGA, AK 99769\n(63.6687, -17...
# 1  Transformation  AKIACHAK 51100\nAKIACHAK, AK 99551\n(60.8911, ...
# 2  Transformation  169 MAIN ST\nGAMBELL, AK 99742\n(63.7413, -171...
# 3  Transformation  1775 WEST PARKS HWY\nWASILLA, AK 99654\n(61.57...
# 4  Transformation     AKIAK 5227\nAKIAK, AK 99552\n(60.8879, -161.2)

# %% [markdown]
# ### Show basic descriptives for each column/variable

# %%
df.describe()
# Out:
#                School Name          City State         District Name  \
# count                  831           831   831                   831
# unique                 821           424    50                   421
# top     BURBANK ELEMENTARY  PHILADELPHIA    CA  PHILADELPHIA CITY SD
# freq                     2            29    92                    27
#
#        2010/11/Award Amount  Model Selected  \
# count                   757             825
# unique                  651               4
# top                   $2.00  Transformation
# freq                     17             608
#
#                                                  Location
# count                                                 831
# unique                                                823
# top     6941 NORTH CENTRAL ST\nPORTLAND, OR 97203\n(45...
# freq                                                    3

# %% [markdown]
# ### Looks like only 4 types of "Model Selected"; let's see what they are

# %%
df["Model Selected"].unique()
# Out:
# array(['Transformation', 'Restart', 'Turnaround', 'Closure', nan],
#       dtype=object)

# %% [markdown]
# ### OK, how many of each?

# %%
model = df["Model Selected"]
model.value_counts()
# Out:
# Transformation    608
# Turnaround        168
# Restart            33
# Closure            16
# Name: Model Selected, dtype: int64

# %% [markdown]
# ### Now let's look at amounts.  A histogram to show frequency distribution...
# - Also, I want to make a new column for "Amount", to convert it to numeric values and to rename the column for easier analysis.

# %%
df["amount"] = pd.to_numeric(df["2010/11/Award Amount"].str.replace("$", ""))
amt = df["amount"]
iplot(
    go.Figure(
        data=[
            go.Histogram(x=amt)
        ],
        layout=dict(title="Figure 1: Frequency of Amounts, $50K Increments")
    )
)
# Out:
# <div id="2241a577-d60a-404d-ad1a-583d02e045c5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '2241a577-d60a-404d-ad1a-583d02e045c5',
#             [{"x": [471014.0, 520579.0, 449592.0, 641184.0, 399686.0, 697703.0, 427658.0, 110544.0, 12973.0, 199828.0, 165903.0, 121657.0, 914557.0, 198953.0, 118394.0, 143238.0, 151116.0, 163619.0, 665000.0, 198728.0, 991451.0, 990135.0, 197012.0, 695000.0, 198783.0, 847003.0, 381512.0, 915959.0, 812195.0, 928654.0, 818238.0, 634503.0, 836556.0, 880050.0, 728696.0, 696668.0, 826589.0, 204246.0, 760314.0, 558022.0, 696520.0, 565322.0, 599344.0, 490954.0, 174245.0, 181152.0, 162698.0, 997852.0, 2.0, 743444.0, 179933.0, 530980.0, 188694.0, 2.0, 1795.0, 121793.0, 181577.0, 189201.0, 148577.0, 148665.0, 12252.0, 175737.0, 559268.0, 135806.0, 197223.0, 913211.0, 102906.0, 1177.0, 159471.0, 180738.0, 925749.0, 173752.0, 577030.0, 102743.0, 185886.0, 142575.0, 171031.0, 128129.0, 201467.0, 167368.0, 2.0, 157616.0, 158151.0, 1695.0, 584002.0, 135806.0, 181152.0, 629711.0, 116423.0, 184555.0, 126595.0, 158712.0, 152096.0, 197223.0, 187692.0, 2.0, 17325.0, 630428.0, 140557.0, 180068.0, 194293.0, 173426.0, 126036.0, 49045.0, 148146.0, 122138.0, 133333.0, 174824.0, 155171.0, 17292.0, 144166.0, 189832.0, 197223.0, 179529.0, 126595.0, 19.0, 806917.0, 184271.0, 197223.0, 189229.0, 179747.0, 105245.0, 631759.0, 163043.0, 189181.0, 140097.0, 141497.0, 233414.0, 443230.0, 125599.0, 105585.0, 388816.0, 108247.0, 50000.0, 187562.0, 481154.0, 924081.0, 539797.0, 674025.0, 852911.0, 100778.0, 619609.0, 641451.0, 622865.0, 821295.0, 13729.0, 671148.0, 728445.0, 606822.0, 31935.0, 32491.0, 374767.0, 481016.0, 595238.0, 825829.0, 430568.0, 500000.0, 590000.0, 400000.0, 400000.0, 700000.0, 430569.0, 800000.0, 700000.0, 590000.0, 400000.0, 700000.0, 700000.0, 700000.0, 517340.0, 445400.0, 517340.0, 330050.0, 619950.0, 189350.0, 552658.0, 180700.0, 541226.0, 305325.0, 630295.0, 672921.0, 394739.0, 733198.0, 115447.0, 660025.0, 737977.0, 759293.0, 816787.0, 652558.0, 713746.0, 759293.0, 728868.0, 845263.0, 734298.0, 759293.0, 500000.0, 500000.0, 258108.0, 737052.0, 711587.0, 666136.0, 108015.0, 660025.0, 617334.0, 737977.0, 618351.0, 515138.0, 713746.0, 759293.0, 736088.0, 440823.0, 647552.0, 500000.0, 500000.0, 267620.0, 737052.0, 636816.0, 10496.0, 276644.0, 698427.0, 652965.0, 796553.0, 567148.0, 759293.0, 784700.0, 651787.0, 627776.0, 676989.0, 500000.0, 407497.0, 759293.0, 713451.0, 759293.0, 251911.0, 759293.0, 644329.0, 660025.0, 344819.0, 518789.0, 652792.0, 742472.0, 713746.0, 697645.0, 997322.0, 628602.0, 635832.0, 500000.0, 500000.0, 369914.0, 759293.0, 633527.0, 506738.0, 115158.0, 955121.0, 115976.0, 11667.0, 185136.0, 144427.0, 942738.0, 107896.0, 788579.0, 146453.0, 139306.0, 122676.0, 147015.0, 119812.0, 102187.0, 101486.0, 164154.0, 868746.0, 105401.0, 125013.0, 688641.0, 112362.0, 902342.0, 663957.0, 140653.0, 876027.0, 18.0, 2.0, null, 18.0, 761197.0, null, 209893.0, null, null, null, null, 286787.0, 170473.0, 122159.0, 195114.0, 11848.0, 198187.0, 170473.0, 793604.0, 185042.0, 170473.0, 179737.0, 113677.0, 199941.0, 198496.0, 735737.0, 191676.0, 552282.0, 199958.0, 108003.0, 197018.0, 764280.0, 180378.0, 18984.0, 1997.0, 429176.0, 588932.0, 433993.0, 437283.0, 559459.0, 498795.0, 437283.0, 395523.0, 808211.0, 437283.0, null, null, 748937.0, 927362.0, 427239.0, 110786.0, 863413.0, 420721.0, 586623.0, 918500.0, 743593.0, 767986.0, 518312.0, 407794.0, 773922.0, 956457.0, 465091.0, 773922.0, 128848.0, 177759.0, 831888.0, 120707.0, 928355.0, 773922.0, 102706.0, null, null, null, null, null, null, 148488.0, 679699.0, 121632.0, 171133.0, 171133.0, 273500.0, 122853.0, 164933.0, 751945.0, 948838.0, 190709.0, 894861.0, 416177.0, 135109.0, 199852.0, 602552.0, 16228.0, 704180.0, 190709.0, 447461.0, 774100.0, 121554.0, 196658.0, 815637.0, 552326.0, 144344.0, 811102.0, 125917.0, 528276.0, 878276.0, 529518.0, 600000.0, 850000.0, 528276.0, 700000.0, 850000.0, 561111.0, 403276.0, 500000.0, 658042.0, 561543.0, 528276.0, 728276.0, 500237.0, 700000.0, 556636.0, 471654.0, 425300.0, 356608.0, 806900.0, 380419.0, 172251.0, 363928.0, 379564.0, 199415.0, 25012 ...

# %% [markdown]
# ### Interesting; a lot of amounts on the low end.  We'll come back to that.
# ### Now I want to see a breakdown of the types of "Models" by State

# %%
state_model = pd.crosstab(index=df["State"], columns=model)
print(state_model)
# Out:
# Model Selected  Closure  Restart  Transformation  Turnaround
# State
# AK                    0        1               6           0
# AL                    0        0              11           0
# AR                    0        0               7           0
# AZ                    0        0              12           7
# CA                    2        5              56          29
# CO                    3        1               9           6
# CT                    0        1               7           6
# DC                    0        3               3           4
# DE                    0        0               2           0
# FL                    0        0              54          17
# GA                    0        0              24           2
# IA                    0        0               6           0
# ID                    0        0               6           0
# IL                    0        1               5           4
# IN                    0        0               4           3
# KS                    0        0               5           1
# KY                    0        0               4           6
# LA                    0        0               2           0
# MA                    0        0               7           5
# MD                    0        5               0           6
# ME                    0        0               5           1
# MI                    0        0              19           9
# MN                    0        0              16           3
# MO                    1        0              17          14
# MS                    0        0               8           0
# MT                    0        0               6           0
# NC                    0        1              17           6
# ND                    0        0               1           0
# NE                    0        0               7           0
# NH                    0        0               7           0
# NJ                    0        1               8           3
# NM                    0        0              12           1
# NV                    0        0               7           3
# NY                    0        0              20           5
# OH                    0        0              27           8
# OK                    0        0               9           1
# OR                    0        0              12           0
# PA                    2        7              43           6
# SC                    1        0              18           0
# SD                    0        0               2           1
# TN                    0        0               6           6
# TX                    0        0              46           2
# UT                    0        0               7           0
# VA                    2        5              11           0
# VT                    0        0              10           0
# WA                    1        0              14           3
# WI                    4        2               5           0
# WV                    0        0              15           0
# WY                    0        0               3           0

# %% [markdown]
# ### Can't think of much to do with that information right now.
# ### I think I just want to see some basic statistics for "Amount":
# - number of schools
# - minimum amount
# - maximum amount
# - mean
# - median
# - standard deviation.

# %%
n = amt.count()
high = amt.max()
low = amt.min()
mean = amt.mean()
median = amt.median()
sd = amt.std()

border = "=================================="

print(border)
print("Number of schools =", n)
print("Maximum =", high)
print("Minimum =", low)
print("Mean =", round(mean, 2))
print("Median =", round(median, 2))
print("Standard Deviation =", round(sd, 2))
print(border)
print("Table 1: Basic Summary Statistics for 'Amount'")
# Out:
# ==================================
# Number of schools = 757
# Maximum = 997852.0
# Minimum = 1.0
# Mean = 420827.89
# Median = 407794.0
# Standard Deviation = 287458.05
# ==================================
# Table 1: Basic Summary Statistics for 'Amount'

# %% [markdown]
# ### About those low values from the histogram...
# - Sort by amount
# - Look at the first bunch of cases, then the next, and see if there are any patterns.
# - I went by groups of 10, which showed that the first 40 give us some information.

# %%
df.sort_values('amount').iloc[0:39]
# Out:
#                                School Name              City State  \
# 643               EDISON HS/FAREIRA SKILLS      PHILADELPHIA    PA
# 80                       BARTON ELEMENTARY    SAN BERNARDINO    CA
# 553  WOODWARD CAREER TECHNICAL HIGH SCHOOL        CINCINNATI    OH
# 538               HUGHES ELEMENTARY SCHOOL          SYRACUSE    NY
# 279                      NORTH HIGH SCHOOL        DES MOINES    IA
# 48                            PACIFIC HIGH    SAN BERNARDINO    CA
# 531                  EMERSON MIDDLE SCHOOL           YONKERS    NY
# 541                    BENNETT HIGH SCHOOL           BUFFALO    NY
# 528                   INTERNATIONAL SCHOOL           BUFFALO    NY
# 527             DELAWARE ELEMENTARY SCHOOL          SYRACUSE    NY
# 545              GEORGE FOWLER HIGH SCHOOL          SYRACUSE    NY
# 524                  ROOSEVELT HIGH SCHOOL           YONKERS    NY
# 95                    SHANDIN HILLS MIDDLE    SAN BERNARDINO    CA
# 53                       SAN GORGONIO HIGH    SAN BERNARDINO    CA
# 502                        CROWNPOINT HIGH        CROWNPOINT    NM
# 521                 SOUTH PARK HIGH SCHOOL           BUFFALO    NY
# 759                     T.C. WILLIAMS HIGH        ALEXANDRIA    VA
# 503                      ERNIE PYLE MIDDLE       ALBUQUERQUE    NM
# 500                 EL CAMINO REAL ACADEMY       ALBUQUERQUE    NM
# 658                             LINCOLN HS      PHILADELPHIA    PA
# 506                           NEWCOMB HIGH           NEWCOMB    NM
# 499                      LAGUNA-ACOMA HIGH        NEW LAGUNA    NM
# 529       FRANKLIN D ROOSEVELT HIGH SCHOOL          BROOKLYN    NY
# 278                    WEEKS MIDDLE SCHOOL        DES MOINES    IA
# 536                   FLUSHING HIGH SCHOOL          FLUSHING    NY
# 523           LONG ISLAND CITY HIGH SCHOOL  LONG ISLAND CITY    NY
# 281                     HOYT MIDDLE SCHOOL        DES MOINES    IA
# 115                     ARROYO VALLEY HIGH    SAN BERNARDINO    CA
# 629                    MCKEESPORT AREA SHS       MC KEESPORT    PA
# 436              W A HIGGINS MIDDLE SCHOOL        CLARKSDALE    MS
# 505                    RAMIREZ THOMAS ELEM          SANTA FE    NM
# 433             LEFLORE COUNTY HIGH SCHOOL         ITTA BENA    MS
# 438                PORT GIBSON HIGH SCHOOL       PORT GIBSON    MS
# 577                    WELCOME CENTER HIGH          COLUMBUS    OH
# 791                GRANDVIEW MIDDLE SCHOOL         GRANDVIEW    WA
# 67                  PHARIS F. FEDDE MIDDLE  HAWAIIAN GARDENS    CA
# 812                BRADLEY TECHNOLOGY HIGH         MILWAUKEE    WI
# 569                SOUTHMOOR MIDDLE SCHOOL          COLUMBUS    OH
# 556              KEIFER ALTERNATIVE CENTER       SPRINGFIELD    OH
#
#                                    District Name 2010/11/Award Amount  \
# 643                         PHILADELPHIA CITY SD                $1.00
# 80                   SAN BERNARDINO CITY UNIFIED                $2.00
# 553                              CINCINNATI CITY                $2.00
# 538                SYRACUSE CITY SCHOOL DISTRICT                $2.00
# 279  DES MOINES INDEPENDENT COMM SCHOOL DISTRICT                $2.00
# 48                   SAN BERNARDINO CITY UNIFIED                $2.00
# 531                 YONKERS CITY SCHOOL DISTRICT                $2.00
# 541                 BUFFALO CITY SCHOOL DISTRICT                $2.00
# 528                 BUFFALO CITY SCHOOL DISTRICT                $2.00
# 527                SYRACUSE CITY SCHOOL DISTRICT                $2.00
# 545                SYRACUSE CITY SCHOOL DISTRICT                $2.00
# 524                 YONKERS CITY SCHOOL DISTRICT                $2.00
# 95                   SAN BERNARDINO CITY UNIFIED                $2.00
# 53                   SAN BERNARDINO CITY UNIFIED                $2.00
# 502                  GALLUP-MCKINLEY CTY SCHOOLS                $2.00
# 521                 BUFFALO CITY SCHOOL DISTRICT                $2.00
# 759                    ALEXANDRIA CITY PBLC SCHS                $2.00
# 503                   ALBUQUERQUE PUBLIC SCHOOLS                $2.00
# 500                   ALBUQUERQUE PUBLIC SCHOOLS               $11.00
# 658                         PHILADELPHIA CITY SD               $14.00
# 506                 CENTRAL CONSOLIDATED SCHOOLS               $15.00
# 499                 GRANTS-CIBOLA COUNTY SCHOOLS               $15.00
# 529        NEW YORK CITY GEOGRAPHIC DISTRICT #20               $18.00
# 278  DES MOINES INDEPENDENT COMM SCHOOL DISTRICT               $18.00
# 536        NEW YORK CITY GEOGRAPHIC DISTRICT #25               $18.00
# 523        NEW YORK CITY GEOGRAPHIC DISTRICT #30               $18.00
# 281  DES MOINES INDEPENDENT COMM SCHOOL DISTRICT               $18.00
# 115                  SAN BERNARDINO CITY UNIFIED               $19.00
# 629                           MCKEESPORT AREA SD              $112.00
# 436             CLARKSDALE MUNICIPAL SCHOOL DIST              $125.00
# 505                      SANTA FE PUBLIC SCHOOLS              $125.00
# 433                       LEFLORE CO SCHOOL DIST              $175.00
# 438                     CLAIBORNE CO SCHOOL DIST              $175.00
# 577                                COLUMBUS CITY             $1036.00
# 791                    GRANDVIEW SCHOOL DISTRICT             $1055.00
# 67                                   ABC UNIFIED             $1177.00
# 812                    MILWAUKEE SCHOOL DISTRICT             $1202.00
# 569                                COLUMBUS CITY             $1264.00
# 556                             SPRINGFIELD CITY             $1657.00
#
#      Model Selected                                           Location  amount
# 643  Transformation  151 WEST LUZERNE ST\nPHILADELPHIA, PA 19140\n(...     1.0
# 80       Turnaround  2214 PUMALO ST\nSAN BERNARDINO, CA 92404\n(34....     2.0
# 553  Transformation  7005 READING RD\nCINCINNATI, OH 45237\n(39.185...     2.0
# 538  Transformation  345 JAMESVILLE AVE\nSYRACUSE, NY 13210\n(43.02...     2.0
# 279  Transformation  501 HOLCOMB AVE\nDES MOINES, IA 50313\n(41.617...     2.0
# 48   Transformation  1020 PACIFIC ST\nSAN BERNARDINO, CA 92404\n(34...     2.0
# 531      Turnaround  160 BOLMER AVE\nYONKERS, NY 10703\n(40.9625, -...     2.0
# 541  Transformation  2885 MAIN ST\nBUFFALO, NY 14214\n(42.9448, -78...     2.0
# 528  Transformation  425 SOUTH PARK AVE\nBUFFALO, NY 14213\n(42.871...     2.0
# 527  Transformation  900 SOUTH GEDDES ST\nSYRACUSE, NY 13204\n(43.0...     2.0
# 545  Transformation  227 MAGNOLIA ST\nSYRACUSE, NY 13204\n(43.044, ...     2.0
# 524  Transformation  631 TUCKAHOE RD\nYONKERS, NY 10710\n(40.9538, ...     2.0
# 95       Turnaround  4301 LITTLE MOUNTAIN DR\nSAN BERNARDINO, CA 92...     2.0
# 53   Transformation  2299 EAST PACIFIC AVE\nSAN BERNARDINO, CA 9240...     2.0
# 502  Transformation  1 CHACO DR\nCROWNPOINT, NM 87313\n(35.6963, -1...     2.0
# 521  Transformation  333 CLINTON ST\nBUFFALO, NY 14204\n(42.8832, -...     2.0
# 759  Transformation  3330 KING ST\nALEXANDRIA, VA 22302\n(38.8248, ...     2.0
# 503  Transformation  1820 VALDORA DR SW\nALBUQUERQUE, NM 87105\n(35...     2.0
# 500  Transformation  3713 ISLETA BLVD SW\nALBUQUERQUE, NM 87105\n(3...    11.0
# 658  Transformation  3201 RYAN AVE\nPHILADELPHIA, PA 19136\n(40.040...    14.0
# 506  Transformation  US HWY 491 SOUTH\nNEWCOMB, NM 87455\n(36.2872,...    15.0
# 499  Transformation  HWY 66\nNEW LAGUNA, NM 87038\n(35.0463, -107.413)    15.0
# 529  Transformation  5800 20TH AVE\nBROOKLYN, NY 11204\n(40.6205, -...    18.0
# 278  Transformation  901 EAST PARK AVE\nDES MOINES, IA 50315\n(41.5...    18.0
# 536  Transformation  35-01 UNION ST\nFLUSHING, NY 11354\n(40.7653, ...    18.0
# 523  Transformation  14-30 BRDWAY\nLONG ISLAND CITY, NY 11106\n(40....    18.0
# 281  Transformation  2700 EAST 42ND ST\nDES MOINES, IA 50317\n(41.6...    18.0
# 115  Transformation  1881 WEST BASELINE ST\nSAN BERNARDINO, CA 9241...    19.0
# 629  Transformation  1960 EDEN PARK BLVD\nMC KEESPORT, PA 15132\n(4...   112.0
# 436  Transformation  1749 CHESNUT ST\nCLARKSDALE, MS 38614\n(34.194...   125.0
# 505      Turnaround  610 ALTA VISTA\nSANTA FE, NM 87505\n(35.6705, ...   125.0
# 433  Transformation  401 LAKESIDE DR\nITTA BENA, MS 38941\n(33.4896...   175.0
# 438  Transformation  159 OLD HWY 18 1\nPORT GIBSON, MS 39150\n(31.9...   175.0
# 577  Transformation  2001 HAMILTON AVE\nCOLUMBUS, OH 43211\n(40.006...  1036.0
# 791  Transformation  1401 WEST 2ND ST\nGRANDVIEW, WA 98930\n(46.254...  1055.0
# 67   Transformation  21409 SOUTH ELAINE AVE\nHAWAIIAN GARDENS, CA 9...  1177.0
# 812  Transformation  700 SOUTH FOURTH ST\nMILWAUKEE, WI 53204\n(43....  1202.0
# 569  Transformation  1201 MOLER RD\nCOLUMBUS, OH 43207\n(39.932, -8...  1264.0
# 556  Transformation  601 SELMA RD\nSPRINGFIELD, OH 45505\n(39.9139,...  1657.0

# %% [markdown]
# ### Interesting that there are a bunch of 1's and 2's, then some amounts in the teens, then 100's, then 1000's...
# - I'm thinking this is an issue of scale; the 1's and 2's should have been x100000, the teens x10000, and so on...
# - Without more information, though, I don't feel like I can make any corrections.
# #### Actually, if I look back at my histogram, it looks like if I remove amounts < 200K, it may be close to a normal distribution (though a bit flat).  Still, I don't know enough about the collection methods at this point to feel comfortable doing that.

# %% [markdown]
# ### We know from our initial description of the file that we have some missing amounts (831 entries vs. 757 amounts, so we should find 74 missing).  Let's look at those.

# %%
no_amt = pd.DataFrame(df[df['amount'].isnull()])
no_amt.head(10)
# Out:
#                               School Name           City State  \
# 280             LINCOLN ELEMENTARY SCHOOL       WATERLOO    IA
# 283             EDMUNDS FINE ARTS ACADEMY     DES MOINES    IA
# 285           FORT HALL ELEMENTARY SCHOOL      POCATELLO    ID
# 286                   MELBA MIDDLE SCHOOL          MELBA    ID
# 287            LAKESIDE ELEMENTARY SCHOOL         WORLEY    ID
# 288            SNAKE RIVER JR HIGH SCHOOL      BLACKFOOT    ID
# 323  SARAH TOWLES REED SENIOR HIGH SCHOOL    NEW ORLEANS    LA
# 324                ASSUMPTION HIGH SCHOOL  NAPOLEONVILLE    LA
# 348     GOVERNOR JAMES B LONGLEY ELEM SCH       LEWISTON    ME
# 349               LAKE REGION HIGH SCHOOL         NAPLES    ME
#
#                                    District Name 2010/11/Award Amount  \
# 280                WATERLOO COMM SCHOOL DISTRICT                  NaN
# 283  DES MOINES INDEPENDENT COMM SCHOOL DISTRICT                  NaN
# 285                           BLACKFOOT DISTRICT                  NaN
# 286                         MELBA JOINT DISTRICT                  NaN
# 287                PLUMMER-WORLEY JOINT DISTRICT                  NaN
# 288                         SNAKE RIVER DISTRICT                  NaN
# 323                 RECOVERY SCHOOL DISTRICT-LDE                  NaN
# 324                            ASSUMPTION PARISH                  NaN
# 348                   LEWISTON SCHOOL DEPARTMENT                  NaN
# 349                                      MSAD 61                  NaN
#
#      Model Selected                                           Location  amount
# 280  Transformation  302 CEDAR BEND\nWATERLOO, IA 50703\n(42.5186, ...     NaN
# 283  Transformation  1601 CROCKER ST\nDES MOINES, IA 50314\n(41.594...     NaN
# 285  Transformation      B ST\nPOCATELLO, ID 83202\n(42.906, -112.582)     NaN
# 286  Transformation   560 BRDWAY\nMELBA, ID 83641\n(43.3785, -116.531)     NaN
# 287  Transformation  S 29900 FIRST AVE\nWORLEY, ID 83876\n(47.4, -1...     NaN
# 288  Transformation  918 WEST HWY 39\nBLACKFOOT, ID 83221\n(43.197,...     NaN
# 323  Transformation  5316 MICHOUD BLVD\nNEW ORLEANS, LA 70129\n(30....     NaN
# 324  Transformation  4880 HWY 308\nNAPOLEONVILLE, LA 70390\n(29.941...     NaN
# 348      Turnaround  145 BIRCH ST\nLEWISTON, ME 4240\n(44.0943, -70...     NaN
# 349  Transformation  1877 ROOSEVELT TRAIL\nNAPLES, ME 4055\n(43.996...     NaN

# %% [markdown]
# ### There they are.  Nothing sticks out at first glance, so let's "describe" the data frame.

# %%
no_amt.describe(include='all')
# Out:
#        School Name         City State District Name  2010/11/Award Amount  \
# count           74           74    74            74                   0.0
# unique          74           47     9            51                   0.0
# top     TRAVIS H S  SAN ANTONIO    TX   HOUSTON ISD                   NaN
# freq             1            8    48             6                   NaN
# mean           NaN          NaN   NaN           NaN                   NaN
# std            NaN          NaN   NaN           NaN                   NaN
# min            NaN          NaN   NaN           NaN                   NaN
# 25%            NaN          NaN   NaN           NaN                   NaN
# 50%            NaN          NaN   NaN           NaN                   NaN
# 75%            NaN          NaN   NaN           NaN                   NaN
# max            NaN          NaN   NaN           NaN                   NaN
#
#         Model Selected                                           Location  \
# count               68                                                 74
# unique               2                                                 74
# top     Transformation  2524 WEST LEDBETTER DR\nDALLAS, TX 75233\n(32....
# freq                65                                                  1
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#         amount
# count      0.0
# unique     NaN
# top        NaN
# freq       NaN
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# #### So, we knew there were 74 missing amounts, but now we also know that those missing amounts consist of 74 unique schools in 51 unique districts, in 47 cities, across 9 states.

# %% [markdown]
# ## At this point, I want to look at the breakdown of amounts for the "Model Selected" and "State" variables.
#
# ### First, I'll look at the mean amount for each type of model, keeping in mind that the means will be affected by those small amounts.

# %%
model_means = df['amount'].groupby(df["Model Selected"]).mean()

print(border)
print(round(model_means, 2))
print(border)
print("Table 2: Mean Amounts by Model Type")
# Out:
# ==================================
# Model Selected
# Closure            75155.50
# Restart           503412.42
# Transformation    434116.06
# Turnaround        394100.58
# Name: amount, dtype: float64
# ==================================
# Table 2: Mean Amounts by Model Type

# %% [markdown]
# ### Then, I want to see the total grant funds distributed for each state...

# %%
state_sums = df['amount'].groupby(df['State']).sum().reset_index()
state_sums
# Out:
#    State      amount
# 0     AK   3607416.0
# 1     AL   2300782.0
# 2     AR   3936109.0
# 3     AZ  13181345.0
# 4     CA  20286824.0
# 5     CO  10158232.0
# 6     CT   8041137.0
# 7     DC   4199339.0
# 8     DE   1303216.0
# 9     FL  43138859.0
# 10    GA   8892929.0
# 11    IA    761235.0
# 12    ID    496680.0
# 13    IL   2197110.0
# 14    IN   2191767.0
# 15    KS   1270660.0
# 16    KY   5025938.0
# 17    LA         0.0
# 18    MA   7441266.0
# 19    MD   6033577.0
# 20    ME         0.0
# 21    MI  10893630.0
# 22    MN  11633397.0
# 23    MO  13215147.0
# 24    MS   1250153.0
# 25    MT   1961690.0
# 26    NC  13527138.0
# 27    ND    418574.0
# 28    NE   4078079.0
# 29    NH   2661604.0
# 30    NJ   2158303.0
# 31    NM   1975170.0
# 32    NV   4991568.0
# 33    NY   5668851.0
# 34    OH  15266786.0
# 35    OK   2770485.0
# 36    OR   5792028.0
# 37    PA  28318207.0
# 38    RI         0.0
# 39    SC  11272707.0
# 40    SD    530890.0
# 41    TN   4997708.0
# 42    TX         0.0
# 43    UT   4251625.0
# 44    VA   8008990.0
# 45    VT   2750483.0
# 46    WA   6569211.0
# 47    WI   3176096.0
# 48    WV   4961093.0
# 49    WY   1002682.0

# %% [markdown]
# #### ... which would look much better on a map.

# %%
iplot(
    go.Figure(
        data = [ dict(
            type='choropleth',
            autocolorscale = True,
            locations = state_sums['State'],
            z = state_sums['amount'],
            locationmode = 'USA-states',
            marker = dict(
            line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                ) ),
            colorbar = dict(
                title = "USD")
            ) ],

        layout = dict(
            title = 'Figure 2: 2010 School Improvement Grants by State',
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                lakecolor = 'rgb(255, 255, 255)'),
             )
    )
)
# Out:
# <div id="b34a9708-80b5-4101-80ae-a12aaf7e2c1a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'b34a9708-80b5-4101-80ae-a12aaf7e2c1a',
#             [{"autocolorscale": true, "colorbar": {"title": "USD"}, "locationmode": "USA-states", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "z": [3607416.0, 2300782.0, 3936109.0, 13181345.0, 20286824.0, 10158232.0, 8041137.0, 4199339.0, 1303216.0, 43138859.0, 8892929.0, 761235.0, 496680.0, 2197110.0, 2191767.0, 1270660.0, 5025938.0, 0.0, 7441266.0, 6033577.0, 0.0, 10893630.0, 11633397.0, 13215147.0, 1250153.0, 1961690.0, 13527138.0, 418574.0, 4078079.0, 2661604.0, 2158303.0, 1975170.0, 4991568.0, 5668851.0, 15266786.0, 2770485.0, 5792028.0, 28318207.0, 0.0, 11272707.0, 530890.0, 4997708.0, 0.0, 4251625.0, 8008990.0, 2750483.0, 6569211.0, 3176096.0, 4961093.0, 1002682.0], "type": "choropleth", "uid": "64fe653e-e957-11e8-80e0-41113a9d3eed"}],
#             {"geo": {"lakecolor": "rgb(255, 255, 255)", "projection": {"type": "albers usa"}, "scope": "usa", "showlakes": true}, "title": "Figure 2: 2010 School Improvement Grants by State"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('b34a9708-80b5-4101-80ae-a12aaf7e2c1a',{});}).then(function(){Plotly.animate('b34a9708-80b5-4101-80ae-a12aaf7e2c1a');})
#         });</script>

# %% [markdown]
# #### We can clearly see that Florida got the most, followed by Pennsylvania.  A good follow-up to this would be to see how many schools are in each state.

# %% [markdown]
# ### We could further break this down with the city variable, or use the latitude/longitude data contained in the "Location" variable to plot individual schools.
